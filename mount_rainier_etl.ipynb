# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Extract CSV files into DataFrames

# %%
climbing_file = "Resources/climbing_statistics.csv"
climbing_df = pd.read_csv(climbing_file)
climbing_df
# Out:
#             Date                   Route  Attempted  Succeeded  \
# 0     11/27/2015  Disappointment Cleaver          2          0
# 1     11/21/2015  Disappointment Cleaver          3          0
# 2     10/15/2015  Disappointment Cleaver          2          0
# 3     10/13/2015           Little Tahoma          8          0
# 4      10/9/2015  Disappointment Cleaver          2          0
# ...          ...                     ...        ...        ...
# 4072   1/16/2014           Little Tahoma          2          0
# 4073    1/6/2014  Disappointment Cleaver          8          0
# 4074    1/6/2014  Disappointment Cleaver          8          0
# 4075    1/5/2014  Disappointment Cleaver          2          0
# 4076    1/4/2014        Gibralter Ledges          3          2
#
#       Success Percentage
# 0               0.000000
# 1               0.000000
# 2               0.000000
# 3               0.000000
# 4               0.000000
# ...                  ...
# 4072            0.000000
# 4073            0.000000
# 4074            0.000000
# 4075            0.000000
# 4076            0.666667
#
# [4077 rows x 5 columns]

# %%
weather_file = "Resources/Rainier_Weather.csv"
weather_df = pd.read_csv(weather_file)
weather_df
# Out:
#            Date  Battery Voltage AVG  Temperature AVG  Relative Humidity AVG  \
# 0    12/31/2015            13.845000        19.062917              21.870833
# 1    12/30/2015            13.822917        14.631208              18.493833
# 2    12/29/2015            13.834583         6.614292              34.072917
# 3    12/28/2015            13.710417         8.687042              70.557917
# 4    12/27/2015            13.362500        14.140417              95.754167
# ..          ...                  ...              ...                    ...
# 459   9/27/2014            13.467083        33.318750              60.200417
# 460   9/26/2014            13.532500        28.238333             100.000000
# 461   9/25/2014            13.648333        26.823750              99.854167
# 462   9/24/2014            13.168750        29.702917             100.000000
# 463   9/23/2014            13.056667        32.857333             100.000000
#
#      Wind Speed Daily AVG  Wind Direction AVG  Solare Radiation AVG
# 0               21.977792           62.325833             84.915292
# 1                3.540542          121.505417             86.192833
# 2                0.000000          130.291667             85.100917
# 3                0.000000          164.683750             86.241250
# 4                0.000000          268.479167             31.090708
# ..                    ...                 ...                   ...
# 459              7.140917          116.294583            227.597125
# 460              0.897625          259.645833            114.400833
# 461              3.166208          278.604167            142.698917
# 462             45.915000          278.054167             37.873708
# 463             65.110667          254.273333             16.593800
#
# [464 rows x 7 columns]

# %% [markdown]
# # Transform Data

# %%
# Remove unwanted columns from Weather DF
new_weather_df = weather_df[['Date', 'Temperature AVG', 'Relative Humidity AVG', 'Wind Speed Daily AVG']].copy()

renamed_weather_df = new_weather_df.rename(columns={'Date':'date', 'Temperature AVG': 'temp_avg', 
    'Relative Humidity AVG':'relative_humidity_avg', 'Wind Speed Daily AVG': 'wind_speed_daily_avg'})
renamed_weather_df.head()
# Out:
#          date   temp_avg  relative_humidity_avg  wind_speed_daily_avg
# 0  12/31/2015  19.062917              21.870833             21.977792
# 1  12/30/2015  14.631208              18.493833              3.540542
# 2  12/29/2015   6.614292              34.072917              0.000000
# 3  12/28/2015   8.687042              70.557917              0.000000
# 4  12/27/2015  14.140417              95.754167              0.000000

# %%
# Clean climbing statistics data by dropping duplicates and setting the index
new_climbing_df = climbing_df.drop_duplicates(subset =["Date","Route"], keep='last')

renamed_climbing_df = new_climbing_df.rename(columns={'Date':'date', 'Route': 'route', 'Attempted':'attempted',

engine = create_engine(f'postgresql://{connection_string}')

# %% [markdown]
# ## Check for tables

# %%
engine.table_names()
# Out:
# ['weather', 'climbing_statistics']

# %% [markdown]
# ## Load DataFrames into SQL database

# %%
renamed_climbing_df.to_sql(name='climbing_statistics', con=engine, if_exists='append', index=False)

# %%
renamed_weather_df.to_sql(name='weather', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## Scrape Table to add to DB

# %%
url = 'https://www.summitpost.org/mount-rainier/150291#chapter_6'

# %%
tables = pd.read_html(url)
tables
# Out:
# [            0                        1
#  0  Page Type:            Mountain/Rock
#  1    Lat/Lon:   46.85280°N / 121.759°W
#  2  Elevation:        14411 ft / 4392 m
#  3         NaN  Sign the Climber's Log!,
#                     0                     1
#  0           Location  Max Number of People
#  1     Muir Snowfield                    36
#  2          Camp Muir                   110
#  3     Ingraham Flats                    35
#  4        Camp Hazard                    36
#  5  Kautz Alpine Zone                    36
#  6      Camp Schurman                    48
#  7       Emmons Flats                    24
#  8         Thumb Rock                    12
#  9     Rainier Summit                    36,
#                        Route Name  Duration Difficulty (Alpine Grade)  \
#  0         Disappointment Cleaver    2 days                        II
#  1        Ingraham Glacier Direct    2 days                        II
#  2       Ingraham, Gibraltar Rock    2 days                        II
#  3                 Gibraltar Rock  2-3 days                         V
#  4               Gibraltar Ledges    2 days                        II
#  ..                           ...       ...                       ...
#  56           Russell Cliff Gully    2 days                       II+
#  57    Russell Cliff Central Bowl    2 days                       II+
#  58  Russell Cliff Upper Headwall    2 days                       II+
#  59              Winthrop Glacier    2 days                        II
#  60                Emmons Glacier    2 days                        II
#
#     Elevation Gain   Max Grade    SeasonApproach   Unnamed: 6
#  0      9,000 feet  35 degrees     June to Sept.     Paradise
#  1      9,000 feet  35 degrees    January to May     Paradise
#  2      9,000 feet  50 degrees    January to May     Paradise
#  3      9,000 feet  80 degrees    January to May     Paradise
#  4      9,000 feet  50 degrees    January to May     Paradise
#  ..            ...         ...               ...          ...
#  56    10,000 feet  50 degrees   January to July  White River
#  57    10,000 feet  50 degrees   January to July  White River
#  58    10,000 feet  50 degrees   January to July  White River
#  59    10,000 feet  40 degrees  January to Sept.  White River
#  60    10,000 feet  40 degrees  January to Sept.  White River
#
#  [61 rows x 7 columns],
#              0     1    2
#  0       Month  High  Low
#  1     January     7   -3
#  2    February     9   -2
#  3       March    11   -2
#  4       April    17    2
#  5         May    22    6
#  6         Jun    26   10
#  7        July    33   15
#  8      August    32   14
#  9   September    28   12
#  10    October    20    7
#  11   November    14    2
#  12   December     8   -2,
#                                   Thread  Time
#  0                     Personal Websites  5:05
#  1      Bug RE: width, max-width, and...  1:42
#  2  Pair of Mammut Barryvox OPTO 3000...  7:19
#  3        Looking for partners at the...  6:27
#  4                  What's New in Europe  5:21]

# %%
# Select just the first table
route_table = tables[2]
route_table
# Out:
#                       Route Name  Duration Difficulty (Alpine Grade)  \
# 0         Disappointment Cleaver    2 days                        II
# 1        Ingraham Glacier Direct    2 days                        II
# 2       Ingraham, Gibraltar Rock    2 days                        II
# 3                 Gibraltar Rock  2-3 days                         V
# 4               Gibraltar Ledges    2 days                        II
# ..                           ...       ...                       ...
# 56           Russell Cliff Gully    2 days                       II+
# 57    Russell Cliff Central Bowl    2 days                       II+
# 58  Russell Cliff Upper Headwall    2 days                       II+
# 59              Winthrop Glacier    2 days                        II
# 60                Emmons Glacier    2 days                        II
#
#    Elevation Gain   Max Grade    SeasonApproach   Unnamed: 6
# 0      9,000 feet  35 degrees     June to Sept.     Paradise
# 1      9,000 feet  35 degrees    January to May     Paradise
# 2      9,000 feet  50 degrees    January to May     Paradise
# 3      9,000 feet  80 degrees    January to May     Paradise
# 4      9,000 feet  50 degrees    January to May     Paradise
# ..            ...         ...               ...          ...
# 56    10,000 feet  50 degrees   January to July  White River
# 57    10,000 feet  50 degrees   January to July  White River
# 58    10,000 feet  50 degrees   January to July  White River
# 59    10,000 feet  40 degrees  January to Sept.  White River
# 60    10,000 feet  40 degrees  January to Sept.  White River
#
# [61 rows x 7 columns]

# %%
route_table = route_table[['Route Name', 'Difficulty (Alpine Grade)', 'Elevation Gain', 'Max Grade', 'SeasonApproach']]

# %%
route_table
# Out:
#                       Route Name Difficulty (Alpine Grade) Elevation Gain  \
# 0         Disappointment Cleaver                        II     9,000 feet
# 1        Ingraham Glacier Direct                        II     9,000 feet
# 2       Ingraham, Gibraltar Rock                        II     9,000 feet
# 3                 Gibraltar Rock                         V     9,000 feet
# 4               Gibraltar Ledges                        II     9,000 feet
# ..                           ...                       ...            ...
# 56           Russell Cliff Gully                       II+    10,000 feet
# 57    Russell Cliff Central Bowl                       II+    10,000 feet
# 58  Russell Cliff Upper Headwall                       II+    10,000 feet
# 59              Winthrop Glacier                        II    10,000 feet
# 60                Emmons Glacier                        II    10,000 feet
#
#      Max Grade    SeasonApproach
# 0   35 degrees     June to Sept.
# 1   35 degrees    January to May
# 2   50 degrees    January to May
# 3   80 degrees    January to May
# 4   50 degrees    January to May
# ..         ...               ...
# 56  50 degrees   January to July
# 57  50 degrees   January to July
# 58  50 degrees   January to July
# 59  40 degrees  January to Sept.
# 60  40 degrees  January to Sept.
#
# [61 rows x 5 columns]

# %%
# Rename columns
routes = route_table.rename(columns={'Route Name':'route_name', 'Difficulty (Alpine Grade)': 'difficulty_rating', 
    'Elevation Gain': 'elevation_gain', 'Max Grade': 'max_grade', 'SeasonApproach':'season_approach'})
routes
# Out:
#                       route_name difficulty_rating elevation_gain   max_grade  \
# 0         Disappointment Cleaver                II     9,000 feet  35 degrees
# 1        Ingraham Glacier Direct                II     9,000 feet  35 degrees
# 2       Ingraham, Gibraltar Rock                II     9,000 feet  50 degrees
# 3                 Gibraltar Rock                 V     9,000 feet  80 degrees
# 4               Gibraltar Ledges                II     9,000 feet  50 degrees
# ..                           ...               ...            ...         ...
# 56           Russell Cliff Gully               II+    10,000 feet  50 degrees
# 57    Russell Cliff Central Bowl               II+    10,000 feet  50 degrees
# 58  Russell Cliff Upper Headwall               II+    10,000 feet  50 degrees
# 59              Winthrop Glacier                II    10,000 feet  40 degrees
# 60                Emmons Glacier                II    10,000 feet  40 degrees
#
#      season_approach
# 0      June to Sept.
# 1     January to May
# 2     January to May
# 3     January to May
# 4     January to May
# ..               ...
# 56   January to July
# 57   January to July
# 58   January to July
# 59  January to Sept.
# 60  January to Sept.
#
# [61 rows x 5 columns]

# %%
routes.to_sql(name='routes', con=engine, if_exists='append', index=False)
